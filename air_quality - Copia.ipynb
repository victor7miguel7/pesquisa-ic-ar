# %% [markdown]
# # Importando base de dados para análise

# %%
import pandas as pd #
import os
# Out:
# C:\Users\victo\AppData\Local\Temp\ipykernel_18300\3026406390.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
import os
import pandas as pd

# Diretório formatado como raw string (r antes da string)
diretorio = r"C:\Users\victo\Documents\qualidade ar projeto"

# Lista para armazenar DataFrames
lista_dataFrames = []
lista_nome = []

# Iterar sobre os arquivos no diretório
for arq in os.listdir(diretorio):
    if arq.endswith(".csv"):  
        nome_arquivo = "\\" + arq  # Construindo o caminho completo
        caminho_completo = diretorio + nome_arquivo
        nome_df = pd.read_csv(caminho_completo, sep=',', encoding='latin-1')  # Carregar CSV
        print("Nome do arquivo: ", arq)
        lista_dataFrames.append(nome_df)  # Adicionar DataFrame à lista
# Out:
# Nome do arquivo:  IQAir_compazariano_01Nov24-01Dec24_minutely.csv
# Nome do arquivo:  IQAir_compazeduardo_01Nov24-01Dec24_minutely.csv
# Nome do arquivo:  IQAir_CVA_01Nov24-01Dec24_minutely.csv

# %%
# Quantidade de itens na lista
len(lista_dataFrames)
# Out:
# 3

# %%
# Concatenando os arquivos em um único DataFrame
contador = 1
df_concatenado = lista_dataFrames[0]
for i in lista_dataFrames[1:]:
    df_concatenado = pd.concat([df_concatenado, lista_dataFrames[contador]])
    contador += 1

# %%
df_concatenado
# Out:
#             Source                  Timezone       Datetime_start  \
# 0      orew7oys376  America/Recife UTC-03:00  2024-11-01 00:00:00
# 1      orew7oys376  America/Recife UTC-03:00  2024-11-01 00:01:00
# 2      orew7oys376  America/Recife UTC-03:00  2024-11-01 00:02:00
# 3      orew7oys376  America/Recife UTC-03:00  2024-11-01 00:03:00
# 4      orew7oys376  America/Recife UTC-03:00  2024-11-01 00:04:00
# ...            ...                       ...                  ...
# 41799  i2tns66k5l5  America/Recife UTC-03:00  2024-11-30 23:55:00
# 41800  i2tns66k5l5  America/Recife UTC-03:00  2024-11-30 23:56:00
# 41801  i2tns66k5l5  America/Recife UTC-03:00  2024-11-30 23:57:00
# 41802  i2tns66k5l5  America/Recife UTC-03:00  2024-11-30 23:58:00
# 41803  i2tns66k5l5  America/Recife UTC-03:00  2024-11-30 23:59:00
#
#               Datetime_end  AQI US  AQI CN  PM2.5 (ug/m3)  PM10 (ug/m3)  \
# 0      2024-11-01 00:00:59      19       5            3.5           6.5
# ...

# %%
df_concatenado.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 126233 entries, 0 to 41803
# Data columns (total 59 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   Source                    126233 non-null  object
#  1   Timezone                  126233 non-null  object
#  2   Datetime_start            126233 non-null  object
#  3   Datetime_end              126233 non-null  object
#  4   AQI US                    126233 non-null  int64
#  5   AQI CN                    126233 non-null  int64
#  6   PM2.5 (ug/m3)             126233 non-null  float64
#  7   PM10 (ug/m3)              126233 non-null  float64
#  8   PM1 (ug/m3)               126233 non-null  float64
#  9   CO2 (ppm)                 126233 non-null  int64
#  10  CO (ppm)                  0 non-null       float64
#  11  TVOC (index)              0 non-null       float64
#  12  NOx (index)               0 non-null       float64
# ...

# %%
display(df_concatenado['CO (ppm)'])
# Out:
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
#          ..
# 41799   NaN
# 41800   NaN
# 41801   NaN
# 41802   NaN
# 41803   NaN
# Name: CO (ppm), Length: 126233, dtype: float64

# %%
# Contar o número de valores nulos em cada coluna
nulos_por_coluna = df_concatenado.isnull().sum().sort_values(ascending=False)
print(nulos_por_coluna)
# Out:
# slot.1.hcho                 126233
# slot.1.pm10                 126233
# slot.1.pc                   126233
# slot.1.voc                  126233
# slot.1.o3                   126233
# slot.1.co                   126233
# slot.2.co2                  126233
# slot.2.voc                  126233
# slot.2.hcho                 126233
# slot.2.o3                   126233
# slot.2.co                   126233
# slot.3.pm1                  126233
# slot.3.pm10                 126233
# slot.3.pm25                 126233
# slot.3.pc                   126233
# slot.3.voc                  126233
# slot.3.hcho                 126233
# slot.3.o3                   126233
# slot.3.co                   126233
# slot.4.co2                  126233
# slot.4.voc                  126233
# slot.4.hcho                 126233
# slot.4.o3                   126233
# slot.1.pm25                 126233
# slot.4.co                   126233
# slot.1.pm1                  126233
# HCHO (ppb)                  126233
# ...

# %%
# Filtrar colunas com valores nulos maiores ou igual que 0
limite = 0
df_filtrado = df_concatenado.loc[:, df_concatenado.isnull().sum() <= limite]

print(f"Dimensão original: {df_concatenado.shape}")
print(f"Dimensão após filtro: {df_filtrado.shape}")
# Out:
# Dimensão original: (126233, 59)
# Dimensão após filtro: (126233, 23)

# %%
display(df_filtrado)
# Out:
#             Source                  Timezone       Datetime_start  \
# 0      orew7oys376  America/Recife UTC-03:00  2024-11-01 00:00:00
# 1      orew7oys376  America/Recife UTC-03:00  2024-11-01 00:01:00
# 2      orew7oys376  America/Recife UTC-03:00  2024-11-01 00:02:00
# 3      orew7oys376  America/Recife UTC-03:00  2024-11-01 00:03:00
# 4      orew7oys376  America/Recife UTC-03:00  2024-11-01 00:04:00
# ...            ...                       ...                  ...
# 41799  i2tns66k5l5  America/Recife UTC-03:00  2024-11-30 23:55:00
# 41800  i2tns66k5l5  America/Recife UTC-03:00  2024-11-30 23:56:00
# 41801  i2tns66k5l5  America/Recife UTC-03:00  2024-11-30 23:57:00
# 41802  i2tns66k5l5  America/Recife UTC-03:00  2024-11-30 23:58:00
# 41803  i2tns66k5l5  America/Recife UTC-03:00  2024-11-30 23:59:00
#
#               Datetime_end  AQI US  AQI CN  PM2.5 (ug/m3)  PM10 (ug/m3)  \
# 0      2024-11-01 00:00:59      19       5            3.5           6.5
# ...

# %%
df_filtrado.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 126233 entries, 0 to 41803
# Data columns (total 23 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   Source                    126233 non-null  object
#  1   Timezone                  126233 non-null  object
#  2   Datetime_start            126233 non-null  object
#  3   Datetime_end              126233 non-null  object
#  4   AQI US                    126233 non-null  int64
#  5   AQI CN                    126233 non-null  int64
#  6   PM2.5 (ug/m3)             126233 non-null  float64
#  7   PM10 (ug/m3)              126233 non-null  float64
#  8   PM1 (ug/m3)               126233 non-null  float64
#  9   CO2 (ppm)                 126233 non-null  int64
#  10  Temperature (Celsius)     126233 non-null  float64
#  11  Temperature (Fahrenheit)  126233 non-null  float64
#  12  Humidity (%)              126233 non-null  int64
# ...

# %%
display(df_filtrado['Timezone'].unique())
# Out:
# array(['America/Recife UTC-03:00'], dtype=object)

# %%
display(df_filtrado['AQI US'].unique())
# Out:
# array([ 19,  17,  14,  22,  25,  28,  44,  33,  36,  31,  11,  69,  42,
#         47,  39,  52,  50,  53,  54,  58,   8,   6,  55,  77,  60,  66,
#        102, 157, 110,  95,  57,  56,  59,  61,   3,  62,  71,  63,  67,
#         72,  84,  85,  94,  82,  83,  73,  68, 106,  65,  91,  96,  70,
#         64,  74,  75,  81,  87,  92,  78,  80,  86,  76,  79, 115, 112,
#        107, 170, 152, 118, 129, 134, 121,  89, 128, 167, 172, 171, 165,
#        168, 159, 139, 119, 117, 105,  99, 103,  90, 123, 143, 111,  93,
#          0,  88, 153, 179, 203, 192, 147, 175, 155, 144, 158, 169, 164,
#        151, 127, 160, 124,  97, 162, 154, 122, 149, 132, 181, 186, 174,
#        177,  98, 101, 116, 166, 180, 161, 131, 142, 108, 184, 173, 126,
#        156, 208, 201, 234, 310, 385, 423, 389, 334, 257, 290, 259, 202,
#        163, 226, 281, 402, 350, 279, 248, 241, 245, 405, 426, 392, 331,
#        409, 435, 404, 300, 269, 251, 227, 249, 244, 235, 220, 297, 346,
# ...

# %%
#df_filtrado.to_csv('prochat.csv', index= False)

# %%
import numpy as np

# Converter a coluna 'Datetime_start' para datetime
df_filtrado['Datetime_start'] = pd.to_datetime(df_filtrado['Datetime_start'])

# Extrair informações temporais de 'Datetime_start'
df_filtrado['Year'] = df_filtrado['Datetime_start'].dt.year                # Ano
df_filtrado['Month'] = df_filtrado['Datetime_start'].dt.month              # Mês
df_filtrado['Day'] = df_filtrado['Datetime_start'].dt.day                  # Dia
df_filtrado['Hour'] = df_filtrado['Datetime_start'].dt.hour                # Hora
df_filtrado['Weekday'] = df_filtrado['Datetime_start'].dt.weekday # Dia da semana(OBS: Para função weekday a semana vai da contagem segunda 0 ate domingo 6)
df_filtrado['Is_Weekend'] = df_filtrado['Weekday'].isin([5, 6]).astype(int) # Fim de semana

# Estações do ano (baseado no hemisfério sul)
def get_season(month):
    if month in [12, 1, 2]:
        return 'Verão'
    elif month in [3, 4, 5]:
        return 'Outono'
    elif month in [6, 7, 8]:
        return 'Inverno'
    else:
        return 'Primavera'

df_filtrado['Season'] = df_filtrado['Month'].apply(get_season)


# Visualizar as primeiras linhas
df_filtrado.head()
# Out:
# C:\Users\victo\AppData\Local\Temp\ipykernel_18300\2144157949.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtrado['Datetime_start'] = pd.to_datetime(df_filtrado['Datetime_start'])
# C:\Users\victo\AppData\Local\Temp\ipykernel_18300\2144157949.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtrado['Year'] = df_filtrado['Datetime_start'].dt.year                # Ano
# C:\Users\victo\AppData\Local\Temp\ipykernel_18300\2144157949.py:8: SettingWithCopyWarning:
# ...

# %%
# Selecionar as colunas relacionadas a "pm25" e adicionar explicitamente a coluna "PM2.5 (ug/m3)"
colunas_pm25 = [col for col in df_filtrado.columns if "pm25" in col.lower()] + ["PM2.5 (ug/m3)"] + ["AQI US"]

# Criar um DataFrame filtrado apenas com essas colunas
df_filtrado = df_filtrado[colunas_pm25]
df_filtrado.head()
# Out:
#    slot.2.pm25  slot.4.pm25  PM2.5 (ug/m3)  AQI US
# 0            3            4            3.5      19
# 1            2            4            3.0      17
# 2            2            3            2.5      14
# 3            3            4            3.5      19
# 4            4            3            3.5      19

# %%
df_filtrado.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 126233 entries, 0 to 41803
# Data columns (total 4 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   slot.2.pm25    126233 non-null  int64
#  1   slot.4.pm25    126233 non-null  int64
#  2   PM2.5 (ug/m3)  126233 non-null  float64
#  3   AQI US         126233 non-null  int64
# dtypes: float64(1), int64(3)
# memory usage: 4.8 MB

# %%
from sklearn.preprocessing import LabelEncoder
# Instanciando o LabelEncoder
label_encoder = LabelEncoder()

# Transformando as colunas de categorias em números
df_filtrado['Season'] = label_encoder.fit_transform(df_filtrado['Season'])
df_filtrado['Source'] = label_encoder.fit_transform(df_filtrado['Source'])

df_filtrado.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 126233 entries, 0 to 41803
# Data columns (total 25 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   Source                 126233 non-null  int32
#  1   AQI US                 126233 non-null  int64
#  2   PM2.5 (ug/m3)          126233 non-null  float64
#  3   PM10 (ug/m3)           126233 non-null  float64
#  4   PM1 (ug/m3)            126233 non-null  float64
#  5   CO2 (ppm)              126233 non-null  int64
#  6   Temperature (Celsius)  126233 non-null  float64
#  7   Humidity (%)           126233 non-null  int64
#  8   Pressure (pascal)      126233 non-null  int64
#  9   Particle Count         126233 non-null  float64
#  10  slot.2.pm1             126233 non-null  int64
#  11  slot.2.pm10            126233 non-null  int64
#  12  slot.2.pm25            126233 non-null  int64
#  13  slot.2.pc              126233 non-null  int64
# ...

# %%
df_filtrado.tail(10)
# Out:
#        Source  AQI US  PM2.5 (ug/m3)  PM10 (ug/m3)  PM1 (ug/m3)  CO2 (ppm)  \
# 41794       0      50            9.0          24.0          3.0        405
# 41795       0      44            8.0          21.0          3.0        405
# 41796       0      44            8.0          20.0          3.0        406
# 41797       0      50            9.0          24.0          2.0        407
# 41798       0      44            8.0          23.0          2.0        407
# 41799       0      33            6.0          16.0          2.0        404
# 41800       0      39            7.0          16.0          2.0        403
# 41801       0      33            6.0          16.0          2.0        403
# 41802       0      33            6.0          15.0          2.0        403
# 41803       0      33            6.0          14.0          2.0        403
#
#        Temperature (Celsius)  Humidity (%)  Pressure (pascal)  Particle Count  \
# ...

# %%
# Features
X = df_filtrado.drop('AQI US',axis=1)

# Target(alvo)

y = df_filtrado['AQI US']

# %% [markdown]
# # Testando modelos

# %% [markdown]
# # Regressao linear

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import cross_val_score
import numpy
model = LinearRegression()
# Validação Cruzada para R²
r2_scores = cross_val_score(model, X, y, cv=10, scoring='r2')

# Validação Cruzada para MSE
mse_scores = cross_val_score(model, X, y, cv=10, scoring='neg_mean_squared_error')

# Validação Cruzada para MAE
mae_scores = cross_val_score(model, X, y, cv=10, scoring='neg_mean_absolute_error')

# Resultados
print(f"Média do R²: {np.mean(r2_scores):.4f}")
print(f"Média do MSE: {-np.mean(mse_scores):.4f}")  # Inverte o sinal do MSE
print(f"Média do MAE: {-np.mean(mae_scores):.4f}")  # Inverte o sinal do MAE
# Out:
# Média do R²: 0.7781
# Média do MSE: 55.4941
# Média do MAE: 4.3993

# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import cross_val_predict
from sklearn.model_selection import KFold

# Features e Target
X = df_filtrado.drop('AQI US', axis=1)
y = df_filtrado['AQI US']

# Modelo
model = LinearRegression()

# Realiza validação cruzada (obtemos as previsões para cada amostra)
y_predict = cross_val_predict(model, X, y, cv=10)  # cv=10 para 10 folds

# Limita a amostra (por exemplo, os primeiros 20 valores)
n_amostra = 20  # Define o número de amostras a serem exibidas
y_test_amostra = y[:n_amostra]
y_predict_amostra = y_predict[:n_amostra]

# Cria um índice para as posições das barras
indices = np.arange(len(y_test_amostra))

# Largura de cada barra
largura_barra = 0.4

plt.figure(figsize=(20, 10))

# Barras para os valores reais
plt.bar(indices - largura_barra/2, y_test_amostra, width=largura_barra, label='Valor Real')

# Barras para os valores previstos
plt.bar(indices + largura_barra/2, y_predict_amostra, width=largura_barra, label='Valor Previsto')

# Legenda e títulos
plt.legend()
plt.xlabel('Índices')
plt.ylabel('Valores')
plt.title('Comparação entre Valores Reais e Previstos (Amostra Limitada) - Validação Cruzada')

# Exibe o gráfico
plt.show()

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import cross_val_score
import numpy
model = RandomForestRegressor(n_estimators=100, max_depth=None, random_state=42)
r2_scores = cross_val_score(model, X, y, cv=10, scoring='r2')

# Validação Cruzada para MSE
mse_scores = cross_val_score(model, X, y, cv=10, scoring='neg_mean_squared_error')

# Validação Cruzada para MAE
mae_scores = cross_val_score(model, X, y, cv=10, scoring='neg_mean_absolute_error')

# Resultados
print(f"Média do R²: {np.mean(r2_scores):.4f}")
print(f"Média do MSE: {-np.mean(mse_scores):.4f}")  # Inverte o sinal do MSE
print(f"Média do MAE: {-np.mean(mae_scores):.4f}")  # Inverte o sinal do MAE
# Out:
# Média do R²: 0.9996
# Média do MSE: 0.1220
# Média do MAE: 0.0043

# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import cross_val_predict
from sklearn.model_selection import KFold

# Features e Target
X = df_filtrado.drop('AQI US', axis=1)
y = df_filtrado['AQI US']

# Modelo
model = RandomForestRegressor(n_estimators=100, max_depth=None, random_state=42)

# Realiza validação cruzada (obtemos as previsões para cada amostra)
y_predict = cross_val_predict(model, X, y, cv=10)  # cv=10 para 10 folds

# Limita a amostra (por exemplo, os primeiros 20 valores)
n_amostra = 20  # Define o número de amostras a serem exibidas
y_test_amostra = y[:n_amostra]
y_predict_amostra = y_predict[:n_amostra]

# Cria um índice para as posições das barras
indices = np.arange(len(y_test_amostra))

# Largura de cada barra
largura_barra = 0.4

plt.figure(figsize=(20, 10))

# Barras para os valores reais
plt.bar(indices - largura_barra/2, y_test_amostra, width=largura_barra, label='Valor Real')

# Barras para os valores previstos
plt.bar(indices + largura_barra/2, y_predict_amostra, width=largura_barra, label='Valor Previsto')

# Legenda e títulos
plt.legend()
plt.xlabel('Índices')
plt.ylabel('Valores')
plt.title('Comparação entre Valores Reais e Previstos (Amostra Limitada) - Validação Cruzada')

# Exibe o gráfico
plt.show()

# %%
import seaborn as sns

model = RandomForestRegressor(n_estimators=100, max_depth=None, random_state=42)
model.fit(X, y)
# Obtém a importância das features
importancia_features = pd.DataFrame({
    'Feature': X.columns,
    'Importância': model.feature_importances_
}).sort_values(by='Importância', ascending=False)

# Plot do gráfico de importância
plt.figure(figsize=(15, 5))
sns.barplot(x='Feature', y='Importância', data=importancia_features, palette="viridis")
plt.title('Importância das Features no Modelo Random Forest')
plt.xlabel('Features')
plt.ylabel('Importância')
plt.xticks(rotation=90)
plt.show()
# Out:
# C:\Users\victo\AppData\Local\Temp\ipykernel_18300\106868747.py:13: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Feature', y='Importância', data=importancia_features, palette="viridis")

# %% [markdown]
# # Modelo KNN

# %%
from sklearn.neighbors import KNeighborsRegressor
from sklearn.model_selection import cross_val_score
model = KNeighborsRegressor(n_neighbors=7)
r2_scores = cross_val_score(model, X, y, cv=10, scoring='r2')

# Validação Cruzada para MSE
mse_scores = cross_val_score(model, X, y, cv=10, scoring='neg_mean_squared_error')

# Validação Cruzada para MAE
mae_scores = cross_val_score(model, X, y, cv=10, scoring='neg_mean_absolute_error')

# Resultados
print(f"Média do R²: {np.mean(r2_scores):.4f}")
print(f"Média do MSE: {-np.mean(mse_scores):.4f}")  # Inverte o sinal do MSE
print(f"Média do MAE: {-np.mean(mae_scores):.4f}")  # Inverte o sinal do MAE
# Out:
# Média do R²: 0.8521
# Média do MSE: 35.2895
# Média do MAE: 3.3099

# %%
# Features e Target
X = df_filtrado.drop('AQI US', axis=1)
y = df_filtrado['AQI US']

# Modelo
model = KNeighborsRegressor(n_neighbors=7)

# Realiza validação cruzada (obtemos as previsões para cada amostra)
y_predict = cross_val_predict(model, X, y, cv=10)  # cv=10 para 10 folds

# Limita a amostra (por exemplo, os primeiros 20 valores)
n_amostra = 20  # Define o número de amostras a serem exibidas
y_test_amostra = y[:n_amostra]
y_predict_amostra = y_predict[:n_amostra]

# Cria um índice para as posições das barras
indices = np.arange(len(y_test_amostra))

# Largura de cada barra
largura_barra = 0.4

plt.figure(figsize=(20, 10))

# Barras para os valores reais
plt.bar(indices - largura_barra/2, y_test_amostra, width=largura_barra, label='Valor Real')

# Barras para os valores previstos
plt.bar(indices + largura_barra/2, y_predict_amostra, width=largura_barra, label='Valor Previsto')

# Legenda e títulos
plt.legend()
plt.xlabel('Índices')
plt.ylabel('Valores')
plt.title('Comparação entre Valores Reais e Previstos (Amostra Limitada) - Validação Cruzada')

# Exibe o gráfico
plt.show()

# %% [markdown]
# # Modelo SVR

# %%
'''from sklearn.svm import SVR
from sklearn.model_selection import cross_val_score
model = SVR(kernel='rbf', C=1.0, epsilon=0.1)
r2_scores = cross_val_score(model, X, y, cv=10, scoring='r2')

# Validação Cruzada para MSE
mse_scores = cross_val_score(model, X, y, cv=10, scoring='neg_mean_squared_error')

# Validação Cruzada para MAE
mae_scores = cross_val_score(model, X, y, cv=10, scoring='neg_mean_absolute_error')

# Resultados
print(f"Média do R²: {np.mean(r2_scores):.4f}")
print(f"Média do MSE: {-np.mean(mse_scores):.4f}")  # Inverte o sinal do MSE
print(f"Média do MAE: {-np.mean(mae_scores):.4f}")  # Inverte o sinal do MAE'''
